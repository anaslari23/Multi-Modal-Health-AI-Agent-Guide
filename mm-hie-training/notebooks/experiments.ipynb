# %% [markdown]
# # MM-HIE Training Experiments
#
# Use this notebook to prototype training runs for NLP, imaging, vitals, fusion, and the agent.
# Run the corresponding `train_*.py` scripts via the terminal or using `%run` magic.
