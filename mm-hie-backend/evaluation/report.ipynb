# %% [markdown]
# # MM-HIE Evaluation Report
#
# This notebook summarises offline evaluation metrics for all modalities.
# Run `experiment_runner.py` first to populate `evaluation/results/metrics_summary.json` and plots.

# %%
import json
from pathlib import Path

results_path = Path('evaluation/results/metrics_summary.json')
with results_path.open() as f:
    metrics_summary = json.load(f)
metrics_summary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 from pathlib import Path
#       4 results_path = Path('evaluation/results/metrics_summary.json')
# ----> 5 with results_path.open() as f:
#       6     metrics_summary = json.load(f)
#       7 metrics_summary
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/pathlib.py:1242, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1236 def open(self, mode='r', buffering=-1, encoding=None,
#    1237          errors=None, newline=None):
#    1238     """
#    1239     Open the file pointed by this path and return a file object, as
#    1240     the built-in open() function does.
#    1241     """
# -> 1242     return io.open(self, mode, buffering, encoding, errors, newline,
#    1243                    opener=self._opener)
#
# ...
